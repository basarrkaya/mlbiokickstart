# %% [markdown]
# <a href="https://colab.research.google.com/github/basarrkaya/mlbiokickstart/blob/main/githubTrial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world with başar as a computational biologist")
# Out:
# hello world with başar as a computational biologist

# %%
print("we will do good work here")
# Out:
# we will do good work here

# %%
# !git clone https://github.com/basarrkaya/mlbiokickstart
# %cd mlbiokickstart
# Out:
# Cloning into 'mlbiokickstart'...
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 10 (delta 2), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (10/10), done.
# Resolving deltas: 100% (2/2), done.
# /content/mlbiokickstart/Cancer-Multi-Omics-Benchmark/MLOmics/mlbiokickstart

# %%
# !git clone https://github.com/chenzRG/Cancer-Multi-Omics-Benchmark
# %cd Cancer-Multi-Omics-Benchmark
# Out:
# Cloning into 'Cancer-Multi-Omics-Benchmark'...
# remote: Enumerating objects: 1083, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 1083 (delta 7), reused 3 (delta 3), pack-reused 1074 (from 4)
# Receiving objects: 100% (1083/1083), 18.27 MiB | 28.13 MiB/s, done.
# Resolving deltas: 100% (231/231), done.
# /content/mlbiokickstart/Cancer-Multi-Omics-Benchmark/MLOmics/mlbiokickstart/Cancer-Multi-Omics-Benchmark

# %%
# !pip install -r requirements.txt
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.10.0 (from versions: 2.16.0rc0, 2.16.1, 2.16.2, 2.17.0rc0, 2.17.0rc1, 2.17.0, 2.17.1, 2.18.0rc0, 2.18.0rc1, 2.18.0rc2, 2.18.0, 2.18.1, 2.19.0rc0, 2.19.0, 2.19.1, 2.20.0rc0, 2.20.0, 2.21.0rc0, 2.21.0rc1, 2.21.0)
# ERROR: No matching distribution found for tensorflow==2.10.0

# %%
# !rm -rf Main_Dataset
# !chmod +x ./download.sh
# !./download.sh
# Out:
# Cloning into 'MLOmics'...
# remote: Enumerating objects: 435, done.
# remote: Total 435 (delta 0), reused 0 (delta 0), pack-reused 435 (from 1)
# Receiving objects: 100% (435/435), 57.17 KiB | 2.86 MiB/s, done.
# Resolving deltas: 100% (56/56), done.
# Filtering content: 100% (235/235), 8.83 GiB | 27.51 MiB/s, done.
# Main_Dataset Folder has been downloaded and extracted to the current directory.

# %%
import pandas as pd

class_gsbrca_org_methy_df = pd.read_csv('/content/mlbiokickstart/Cancer-Multi-Omics-Benchmark/MLOmics/Main_Dataset/Classification_datasets/GS-BRCA/Original/BRCA_Methy.csv')
class_gsbrca_org_mrna_df = pd.read_csv('/content/mlbiokickstart/Cancer-Multi-Omics-Benchmark/MLOmics/Main_Dataset/Classification_datasets/GS-BRCA/Original/BRCA_mRNA.csv')
class_gsbrca_org_CNV_df = pd.read_csv('/content/mlbiokickstart/Cancer-Multi-Omics-Benchmark/MLOmics/Main_Dataset/Classification_datasets/GS-BRCA/Original/BRCA_CNV.csv')

# %%
class_gsbrca_org_methy_df
# Out:
#       Unnamed: 0  TCGA.3C.AAAU.01  TCGA.3C.AALI.01  TCGA.3C.AALJ.01  \
# 0           A1BG        -1.211396         0.974531         0.633283
# 1           A1CF        -1.801239        -1.091976        -0.258825
# 2            A2M        -0.696763        -1.597015        -0.873714
# 3          A2ML1         0.832338         0.758754         0.753608
# 4        A3GALT2         0.857098         0.450506         0.821330
# ...          ...              ...              ...              ...
# 19044     ZYG11B         1.079773         1.107008         1.143368
# 19045        ZYX         0.780058         0.404568        -0.583163
# 19046      ZZEF1         0.747015         0.107306         0.034379
# 19047       ZZZ3         0.378339         0.271888        -0.170242
# 19048         pk         0.032275        -0.147645         0.748945
#
#        TCGA.3C.AALK.01  TCGA.5L.AAT0.01  TCGA.5T.A9QA.01  TCGA.A1.A0SB.01  \
# 0             0.354642        -1.939963         1.328608         0.946010
# ...

# %%
class_gsbrca_org_CNV_df
# Out:
#       Unnamed: 0  TCGA.3C.AAAU.01  TCGA.3C.AALI.01  TCGA.3C.AALJ.01  \
# 0           A1BG         0.495252         1.028904         0.003059
# 1           A1CF        -0.938762        -1.575977         0.405308
# 2            A2M         0.750838         0.010864         0.103201
# 3          A2ML1         0.748593         0.005894         0.098571
# 4        A3GALT2         1.093743        -1.575680        -0.706498
# ...          ...              ...              ...              ...
# 19563     ZYG11B         1.267331        -1.793233        -0.872324
# 19564        ZYX         0.963246         1.446230         0.039191
# 19565      ZZEF1        -0.580418        -0.790000        -1.421040
# 19566       ZZZ3         1.715811        -1.268621        -0.811368
# 19567         pk        -0.864183         0.345052        -1.357237
#
#        TCGA.3C.AALK.01  TCGA.5L.AAT0.01  TCGA.5T.A9QA.01  TCGA.A1.A0SB.01  \
# 0            -0.258705        -0.083232        -0.486242        -0.111192
# ...

# %%
class_gsbrca_org_mrna_df
# Out:
#       Unnamed: 0  TCGA.3C.AAAU.01  TCGA.3C.AALI.01  TCGA.3C.AALJ.01  \
# 0           A1BG         1.389927         1.522872         1.788271
# 1       A1BG.AS1         0.436758         1.815091         0.580557
# 2            A2M        -0.876187        -0.508085        -0.258138
# 3        A2M.AS1         1.607818         0.863019        -0.491954
# 4          A2ML1        -0.415138        -0.406608        -0.455969
# ...          ...              ...              ...              ...
# 18201     ZYG11A         1.753777         1.298863         2.105007
# 18202     ZYG11B         2.013674        -0.140439        -0.334864
# 18203        ZYX        -0.424991         0.635518         0.573943
# 18204      ZZEF1         1.214399         0.302547        -0.379244
# 18205       ZZZ3         1.667340        -1.162286        -0.547104
#
#        TCGA.3C.AALK.01  TCGA.5L.AAT0.01  TCGA.5T.A9QA.01  TCGA.A1.A0SB.01  \
# 0            -0.288543        -0.462680        -0.451169        -0.805973
# ...
